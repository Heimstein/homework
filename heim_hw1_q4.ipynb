# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
matrix = pd.read_csv('dow_jones_index.csv')
matrix['open']=matrix['open'].str.replace('$','')
matrix['open']=matrix['open'].astype(float)

matrix['high']=matrix['high'].str.replace('$','')
matrix['high']=matrix['high'].astype(float)

matrix['low']=matrix['low'].str.replace('$','')
matrix['low']=matrix['low'].astype(float)

matrix['close']=matrix['close'].str.replace('$','')
matrix['close']=matrix['close'].astype(float)

matrix['next_weeks_open']=matrix['next_weeks_open'].str.replace('$','')
matrix['next_weeks_open']=matrix['next_weeks_open'].astype(float)

matrix['next_weeks_close']=matrix['next_weeks_close'].str.replace('$','')
matrix['next_weeks_close']=matrix['next_weeks_close'].astype(float)

# %%
scatter_matrix(matrix, alpha=0.2, figsize=(50, 50), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002DAB01FB470>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002DAB2919C88>]], dtype=object)

# %%
print(matrix.corr())
# Out:
#                                      quarter      open      high       low  \
# quarter                             1.000000  0.025883  0.024727  0.024730
# open                                0.025883  1.000000  0.999607  0.999344
# high                                0.024727  0.999607  1.000000  0.999419
# low                                 0.024730  0.999344  0.999419  1.000000
# close                               0.022102  0.999044  0.999558  0.999549
# volume                             -0.047599 -0.513424 -0.512240 -0.514850
# percent_change_price               -0.080959  0.061485  0.078656  0.083170
# percent_change_volume_over_last_wk  0.023662 -0.008510 -0.006513 -0.017541
# previous_weeks_volume              -0.057302 -0.511910 -0.511344 -0.511540
# next_weeks_open                     0.021018  0.998942  0.999480  0.999430
# next_weeks_close                    0.019103  0.997787  0.998500  0.998326
# ...
