# %%
dow = read.csv("dow_jones_index.csv")
dow
# Out:
#     quarter stock date      open   high   low    close  volume
# 1   1       AA    1/7/2011  $15.82 $16.72 $15.78 $16.42 239655616
# 2   1       AA    1/14/2011 $16.71 $16.71 $15.64 $15.97 242963398
# 3   1       AA    1/21/2011 $16.19 $16.38 $15.60 $15.79 138428495
# 4   1       AA    1/28/2011 $15.87 $16.63 $15.82 $16.13 151379173
# 5   1       AA    2/4/2011  $16.18 $17.39 $16.18 $17.14 154387761
# 6   1       AA    2/11/2011 $17.33 $17.48 $16.97 $17.37 114691279
# 7   1       AA    2/18/2011 $17.39 $17.68 $17.28 $17.28  80023895
# 8   1       AA    2/25/2011 $16.98 $17.15 $15.96 $16.68 132981863
# 9   1       AA    3/4/2011  $16.81 $16.94 $16.13 $16.58 109493077
# 10  1       AA    3/11/2011 $16.58 $16.75 $15.42 $16.03 114332562
# 11  1       AA    3/18/2011 $15.95 $16.33 $15.43 $16.11 130374108
# 12  1       AA    3/25/2011 $16.38 $17.24 $16.26 $17.09  95550392
# 13  1       AXP   1/7/2011  $43.30 $45.60 $43.11 $44.36  45102042
# ...

# %%
# Basic Scatterplot Matrix
pairs(~quarter+
      stock+
      date+
      open+
      high+
      low+
      close+
      volume+
      percent_change_price+
      percent_change_volume_over_last_wk+
      previous_weeks_volume+
      next_weeks_open+
      next_weeks_close+
      percent_change_next_weeks_price+
      days_to_next_dividend+
      percent_return_next_dividend,
      font.labels = 1,
      data=dow,
   main="Scatterplot Matrix")
# Out:
# plot without title

# %% [markdown]
# Incredibly strong correlation for:
# open-high,
# open-low,
# open-close,
# open-next_weeks_open,
# open-next_weeks_closed,
#
# high-low,
# high-close,
# high-next_weeks_open,
# high-next_weeks_closed,
#
# low-close,
# low-next_weeks_open,
# low-next_weeks_closed,
#
# close-next_weeks_open,
# close-next_weeks_closed,
#
# next_weeks_open-next_weeks_closed,

# %%
x = dow
cor(dow[sapply(dow, function(x) !is.factor(x))])
# Out:
#                                    quarter      volume
# quarter                             1.000000000 -0.04759850
# volume                             -0.047598503  1.00000000
# percent_change_price               -0.080959268 -0.13892399
# percent_change_volume_over_last_wk           NA          NA
# previous_weeks_volume                        NA          NA
# percent_change_next_weeks_price    -0.017459619 -0.05638874
# days_to_next_dividend              -0.025641237 -0.05548638
# percent_return_next_dividend       -0.008504853 -0.26973456
#                                    percent_change_price
# quarter                            -0.080959268
# volume                             -0.138923991
# percent_change_price                1.000000000
# percent_change_volume_over_last_wk           NA
# previous_weeks_volume                        NA
# percent_change_next_weeks_price     0.019955361
# days_to_next_dividend               0.006216923
# ...
